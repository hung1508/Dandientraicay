# %%
import numpy as np
import os
from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x_train= '/content/drive/MyDrive/AI/tien/x_train'
x_test= '/content/drive/MyDrive/AI/tien/x_test'

# %%
x_train = ImageDataGenerator(rescale=1/255)
x_test = ImageDataGenerator(rescale=1/255)

# %%
x_train_data = x_train.flow_from_directory(
    directory=r"/content/drive/MyDrive/AI/money/x_train",
    target_size=(224, 224),
    batch_size=3,
    class_mode='categorical',
    )
x_test_data = x_test.flow_from_directory(
    directory=r"/content/drive/MyDrive/AI/money/x_test",
    target_size=(224, 224),
    batch_size=3,
    class_mode= "categorical",
    )
# Out:
# Found 91 images belonging to 11 classes.
# Found 236 images belonging to 11 classes.

# %%
x_train_data.class_indices
# Out:
# {'100k': 0,
#  '10k': 1,
#  '1k': 2,
#  '200': 3,
#  '200k': 4,
#  '20k': 5,
#  '2k': 6,
#  '500': 7,
#  '500k': 8,
#  '50k': 9,
#  '5k': 10}

# %%
  model = Sequential()

  model.add(Conv2D(32,(3,3),input_shape=(224,224,3),padding='same',activation='relu'))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3),activation='relu',padding='same'))
  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
  model.add(Dropout(0.2))

  model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
  model.add(Dropout(0.2))

  model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Flatten())
  model.add(Dropout(0.2))

  model.add(Dense(1024,activation='relu'))
  model.add(Dropout(0.2))

  model.add(Dense(512,activation='relu'))
  model.add(Dropout(0.2))

  model.add(Dense(11,activation='softmax'))
  model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  dropout (Dropout)           (None, 224, 224, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 64)      18496
#
#  dropout_1 (Dropout)         (None, 112, 112, 64)      0
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 128)       73856
#
#  dropout_2 (Dropout)         (None, 56, 56, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dropout_3 (Dropout)         (None, 100352)            0
#
#  dense (Dense)               (None, 1024)              102761472
#
#  dropout_4 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 11)                5643
#
# =================================================================
# Total params: 103,578,923
# Trainable params: 103,578,923
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
model.compile(optimizer=Adam(learning_rate=0.0005), loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(x_train_data,epochs=30,batch_size=5,verbose=1,validation_data= x_test_data)
# Out:
# Epoch 1/30
# 31/31 [==============================] - 95s 3s/step - loss: 2.4823 - accuracy: 0.1978 - val_loss: 2.4580 - val_accuracy: 0.1271
# Epoch 2/30
# 31/31 [==============================] - 2s 68ms/step - loss: 1.6396 - accuracy: 0.3077 - val_loss: 2.4627 - val_accuracy: 0.0720
# Epoch 3/30
# 31/31 [==============================] - 2s 70ms/step - loss: 1.6900 - accuracy: 0.2527 - val_loss: 2.9560 - val_accuracy: 0.1271
# Epoch 4/30
# 31/31 [==============================] - 2s 69ms/step - loss: 1.5912 - accuracy: 0.1978 - val_loss: 2.9401 - val_accuracy: 0.1271
# Epoch 5/30
# 31/31 [==============================] - 2s 68ms/step - loss: 1.5697 - accuracy: 0.3187 - val_loss: 3.3125 - val_accuracy: 0.1271
# Epoch 6/30
# 31/31 [==============================] - 2s 68ms/step - loss: 1.4780 - accuracy: 0.3516 - val_loss: 2.8811 - val_accuracy: 0.1144
# Epoch 7/30
# 31/31 [==============================] - 2s 69ms/step - loss: 1.3038 - accuracy: 0.4505 - val_loss: 3.4671 - val_accuracy: 0.1780
# Epoch 8/30
# 31/31 [==============================] - 2s 68ms/step - loss: 1.2723 - accuracy: 0.4945 - val_loss: 4.2931 - val_accuracy: 0.2754
# Epoch 9/30
# 31/31 [==============================] - 2s 69ms/step - loss: 1.5182 - accuracy: 0.4396 - val_loss: 3.2463 - val_accuracy: 0.2119
# Epoch 10/30
# 31/31 [==============================] - 2s 68ms/step - loss: 1.3056 - accuracy: 0.4945 - val_loss: 3.6281 - val_accuracy: 0.2839
# Epoch 11/30
# 31/31 [==============================] - 2s 69ms/step - loss: 1.0133 - accuracy: 0.6703 - val_loss: 3.7960 - val_accuracy: 0.2161
# Epoch 12/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.8050 - accuracy: 0.7143 - val_loss: 4.7159 - val_accuracy: 0.2415
# Epoch 13/30
# 31/31 [==============================] - 2s 68ms/step - loss: 0.7540 - accuracy: 0.7473 - val_loss: 4.7921 - val_accuracy: 0.3051
# Epoch 14/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.9107 - accuracy: 0.6813 - val_loss: 4.1838 - val_accuracy: 0.2458
# Epoch 15/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.6052 - accuracy: 0.8132 - val_loss: 9.2561 - val_accuracy: 0.3220
# Epoch 16/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.7406 - accuracy: 0.7143 - val_loss: 4.3867 - val_accuracy: 0.3390
# Epoch 17/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.6914 - accuracy: 0.7912 - val_loss: 5.6422 - val_accuracy: 0.3475
# Epoch 18/30
# 31/31 [==============================] - 3s 85ms/step - loss: 0.5561 - accuracy: 0.7692 - val_loss: 5.3394 - val_accuracy: 0.3432
# Epoch 19/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.2891 - accuracy: 0.9121 - val_loss: 9.4323 - val_accuracy: 0.3559
# Epoch 20/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.6797 - accuracy: 0.7802 - val_loss: 4.1176 - val_accuracy: 0.3136
# Epoch 21/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.4476 - accuracy: 0.8352 - val_loss: 11.9960 - val_accuracy: 0.3771
# Epoch 22/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.7362 - accuracy: 0.7912 - val_loss: 4.8944 - val_accuracy: 0.3305
# Epoch 23/30
# 31/31 [==============================] - 2s 70ms/step - loss: 0.4117 - accuracy: 0.8571 - val_loss: 8.1198 - val_accuracy: 0.3729
# Epoch 24/30
# 31/31 [==============================] - 2s 72ms/step - loss: 0.1064 - accuracy: 0.9670 - val_loss: 16.1349 - val_accuracy: 0.4025
# Epoch 25/30
# 31/31 [==============================] - 2s 78ms/step - loss: 0.4833 - accuracy: 0.9011 - val_loss: 5.0805 - val_accuracy: 0.3305
# Epoch 26/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.3032 - accuracy: 0.8791 - val_loss: 11.1144 - val_accuracy: 0.3644
# Epoch 27/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.4831 - accuracy: 0.8791 - val_loss: 6.0070 - val_accuracy: 0.3644
# Epoch 28/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.1268 - accuracy: 0.9780 - val_loss: 11.9521 - val_accuracy: 0.3814
# Epoch 29/30
# 31/31 [==============================] - 2s 68ms/step - loss: 0.1120 - accuracy: 0.9560 - val_loss: 12.6539 - val_accuracy: 0.3008
# Epoch 30/30
# 31/31 [==============================] - 2s 69ms/step - loss: 0.2558 - accuracy: 0.9560 - val_loss: 8.8697 - val_accuracy: 0.4110

# %%
model.save('nhandientien.h5')

# %%
from keras.models import load_model
recognition = load_model('nhandientien.h5')

# %%
from keras.preprocessing.image import load_img, img_to_array
img = load_img('20k (1).jpg', target_size =(224,224))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,224,224,3)
img = img.astype('float32')
img = img/255
img.shape
# Out:
# (1, 224, 224, 3)

# %%
np.argmax(recognition.predict(img),axis= 1)
# Out:
# array([10])

# %% [markdown]
# x_train_data.class_indices {'100k': 0, '10k': 1, '1k': 2, '200': 3, '200k': 4, '20k': 5, '2k': 6, '500': 7, '500k': 8, '50k': 9, '5k': 10}
